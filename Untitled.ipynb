# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F

# %%
x = torch.randn(12, 12)
plt.imshow(x)
plt.show()

# %%
x = torch.randint(12, (2,))
print(x)
k = torch.exp(- (12) * torch.pow((torch.cartesian_prod(torch.arange(0, 12), torch.arange(0, 12)).float() - x) / 12, 2).sum(axis=-1).reshape(12, 12))
plt.imshow(k)
plt.colorbar()
# Out:
# tensor([9, 7])

# %%
x = torch.randint(12, (2,))
print("x:", x)
y =
